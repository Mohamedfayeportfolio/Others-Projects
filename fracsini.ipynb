# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import CSV

# %%
df = pd.read_csv('crisinfo1.csv', sep=';')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  55.68    5   4  2  186   5
# 2  54.48    7  11  1  246  11
# 3  56.00   10   5  2  104   1
# 4  56.00   10   5  2  104   1

# %%
#rename multiple columns in a list

# %%
df = df.rename(columns = {'NO':'not_outs' , 'HS': 'Highest_innes_score' , 'BF': 'Balls_faced' , 'SR':'Batting_Strik_Rate' , 'Mat':'Matches'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    AC Voges (AUS)  2015-2016       20    31         7  1485
# 2   RG Pollock (SA)  1963-1970       23    41         4  2256
# 3   GA Headley (WI)  1930-1954       22    40         4  2190
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50  0   4s  \
# 0                 334  99.94       9800+               58.60   29  13  7  626
# 1                269*  61.87        2667               55.68    5   4  2  186
# 2                 274  60.97       1707+               54.48    7  11  1  246
# 3                270*  60.83        416+               56.00   10   5  2  104
# 4                270*  60.83        416+               56.00   10   5  2  104
#
#    6s
# 0   6
# 1   5
# 2  11
# 3   1
# 4   1

# %%
#check null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# not_outs               False
# Runs                   False
# Highest_innes_score    False
# Ave                    False
# Balls_faced             True
# Batting_Strik_Rate     False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_faced'].isna()==1]
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 18  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50  0  \
# 18                 220  56.68         NaN                 0.0   15  14  1
#
#      4s  6s
# 18  107  11

# %%
df['Balls_faced'] = df['Balls_faced'].fillna(0)

# %%
df['Batting_Strik_Rate'] = df['Batting_Strik_Rate'].fillna(0)

# %%
df[df['Player']== 'CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 18  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50  0  \
# 18                 220  56.68           0                 0.0   15  14  1
#
#      4s  6s
# 18  107  11

# %%
#drop duplicate

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df[df['Player'].duplicated() ==1]
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 61    V Kohli (IND)  2011-2024      117   199        12  9035
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50   0  \
# 4                 270*  60.83        416+               56.00   10   5   2
# 12                365*  57.78       4063+               53.58   26  30  12
# 16                 211  56.94       5363+               46.22   15  28   4
# 61                254*  48.31       16199               55.77   29  31  15
#
#       4s  6s
# 4    104   1
# 12   593  32
# 16   276   8
# 61  1011  28

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 3   GA Headley (WI)  1930-1954       22    40         4  2190
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 12   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 16   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 60    V Kohli (IND)  2011-2024      117   199        12  9035
# 61    V Kohli (IND)  2011-2024      117   199        12  9035
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50   0  \
# 3                 270*  60.83        416+               56.00   10   5   2
# 4                 270*  60.83        416+               56.00   10   5   2
# 11                365*  57.78       4063+               53.58   26  30  12
# 12                365*  57.78       4063+               53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)','V Kohli (IND)'])]
# Out:
#              Player       Span  Matches  Inns  not_outs  Runs  \
# 3   GA Headley (WI)  1930-1954       22    40         4  2190
# 11   GS Sobers (WI)  1954-1974       93   160        21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 60    V Kohli (IND)  2011-2024      117   199        12  9035
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50   0  \
# 3                 270*  60.83        416+               56.00   10   5   2
# 11                365*  57.78       4063+               53.58   26  30  12
# 15                 211  56.94       5363+               46.22   15  28   4
# 60                254*  48.31       16199               55.77   29  31  15
#
#       4s  6s
# 3    104   1
# 11   593  32
# 15   276   8
# 60  1011  28

# %%
#split up span into start and end dates

# %%
df['Span'].str.split(pat ='-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 62    [1965, 1981]
# 63    [2002, 2014]
# 64    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat ='-').str[1]
# Out:
# 0     1948
# 1     2016
# 2     1970
# 3     1954
# 5     1935
#       ...
# 62    1981
# 63    2014
# 64    1934
# 65    1938
# 66    1934
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_year'] = df['Span'].str.split(pat ='-').str[0]

# %%
df['Final_year'] = df['Span'].str.split(pat ='-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 2     RG Pollock (SA)  1963-1970       23    41         4  2256
# 3     GA Headley (WI)  1930-1954       22    40         4  2190
# 5   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# ..                ...        ...      ...   ...       ...   ...
# 62   KD Walters (AUS)  1965-1981       74   125        14  5357
# 63  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 64  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 65    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 66   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_innes_score    Ave Balls_faced  Batting_Strik_Rate  100  50   0  \
# 0                  334  99.94       9800+               58.60   29  13   7
# ...

# %%
df = df.drop(['Span'],axis = 1 )

# %%
df.head()
# Out:
#               Player  Matches  Inns  not_outs  Runs Highest_innes_score  \
# 0   DG Bradman (AUS)       52    80        10  6996                 334
# 1     AC Voges (AUS)       20    31         7  1485                269*
# 2    RG Pollock (SA)       23    41         4  2256                 274
# 3    GA Headley (WI)       22    40         4  2190                270*
# 5  H Sutcliffe (ENG)       54    84         9  4555                 194
#
#      Ave Balls_faced  Batting_Strik_Rate  100  50  0   4s  6s Rookie_year  \
# 0  99.94       9800+               58.60   29  13  7  626   6        1928
# 1  61.87        2667               55.68    5   4  2  186   5        2015
# 2  60.97       1707+               54.48    7  11  1  246  11        1963
# 3  60.83        416+               56.00   10   5  2  104   1        1930
# 5  60.73       6558+               34.59   16  23  2  202   6        1924
#
#   Final_year
# 0       1948
# 1       2016
# 2       1970
# 3       1954
# 5       1935

# %%
#split up country from the player

# %%
df['Player'].str.split(pat ='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 5     [H Sutcliffe , ENG)]
#               ...
# 62     [KD Walters , AUS)]
# 63    [GC Smith , ICC/SA)]
# 64    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['country']= df['Player'].str.split(pat ='(').str[1]

# %%
df['country']
# Out:
# 0        AUS)
# 1        AUS)
# 2         SA)
# 3         WI)
# 5        ENG)
#        ...
# 62       AUS)
# 63    ICC/SA)
# 64       AUS)
# 65       AUS)
# 66       ENG)
# Name: country, Length: 63, dtype: object

# %%
df['country'].str.split(pat =')').str[0]
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 5        ENG
#        ...
# 62       AUS
# 63    ICC/SA
# 64       AUS
# 65       AUS
# 66       ENG
# Name: country, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat ='(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Inns  not_outs  Runs Highest_innes_score    Ave  \
# 0   DG Bradman        52    80        10  6996                 334  99.94
# 1     AC Voges        20    31         7  1485                269*  61.87
# 2   RG Pollock        23    41         4  2256                 274  60.97
# 3   GA Headley        22    40         4  2190                270*  60.83
# 5  H Sutcliffe        54    84         9  4555                 194  60.73
#
#   Balls_faced  Batting_Strik_Rate  100  50  0   4s  6s Rookie_year Final_year  \
# 0       9800+               58.60   29  13  7  626   6        1928       1948
# 1        2667               55.68    5   4  2  186   5        2015       2016
# 2       1707+               54.48    7  11  1  246  11        1963       1970
# 3        416+               56.00   10   5  2  104   1        1930       1954
# 5       6558+               34.59   16  23  2  202   6        1924       1935
#
#   country
# 0    AUS)
# 1    AUS)
# 2     SA)
# ...

# %%
#change datatypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# not_outs                 int64
# Runs                     int64
# Highest_innes_score     object
# Ave                    float64
# Balls_faced             object
# Batting_Strik_Rate     float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_year             object
# Final_year              object
# country                 object
# dtype: object

# %%
df['Highest_innes_score'].str.split(pat ='*')
# Out:
# 0       [334]
# 1     [269, ]
# 2       [274]
# 3     [270, ]
# 5       [194]
#        ...
# 62      [250]
# 63      [277]
# 64      [266]
# 65      [232]
# 66      [127]
# Name: Highest_innes_score, Length: 63, dtype: object

# %%
 df['Highest_innes_score'].str.split(pat ='*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_innes_score, Length: 63, dtype: object

# %%
df['Matches'] = df['Matches'].astype(str).str.split(pat='*').str[0]

# %%
df['Matches'] = df['Matches'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# not_outs                 int64
# Runs                     int64
# Highest_innes_score     object
# Ave                    float64
# Balls_faced             object
# Batting_Strik_Rate     float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_year             object
# Final_year              object
# country                 object
# dtype: object

# %%
#Question see if you can fix rookie year and final year

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# not_outs                 int64
# Runs                     int64
# Highest_innes_score     object
# Ave                    float64
# Balls_faced             object
# Batting_Strik_Rate     float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_year             object
# Final_year              object
# country                 object
# dtype: object

# %%
df = df.astype({'Rookie_year':'int','Final_year':'int'})

# %%
df = df.drop(57, axis = 0)

# %%
df
# Out:
#           Player  Matches  Inns  not_outs  Runs Highest_innes_score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      AC Voges        20    31         7  1485                269*  61.87
# 2    RG Pollock        23    41         4  2256                 274  60.97
# 3    GA Headley        22    40         4  2190                270*  60.83
# 5   H Sutcliffe        54    84         9  4555                 194  60.73
# ..           ...      ...   ...       ...   ...                 ...    ...
# 62   KD Walters        74   125        14  5357                 250  48.26
# 63     GC Smith       117   205        13  9265                 277  48.25
# 64  WH Ponsford        29    48         4  2122                 266  48.22
# 65    SJ McCabe        39    62         5  2748                 232  48.21
# 66   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# not_outs               False
# Runs                   False
# Highest_innes_score    False
# Ave                    False
# Balls_faced            False
# Batting_Strik_Rate     False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_year            False
# Final_year             False
# country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# not_outs                 int64
# Runs                     int64
# Highest_innes_score     object
# Ave                    float64
# Balls_faced             object
# Batting_Strik_Rate     float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_year              int32
# Final_year               int32
# country                 object
# dtype: object

# %%
# Remove non-numeric characters, such as the '+' at the end of some numbers

# %%
df['Balls_faced'] = df['Balls_faced'].str.replace('+', '','-' , regex=False)

# %%
# Replace missing values (NaN) with 0 or another default value, if necessary

# %%
df['Balls_faced'] = df['Balls_faced'].fillna(0)

# %%
# Convert the column to an integer

# %%
df['Balls_faced'] = df['Balls_faced'].astype(int)

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# not_outs                 int64
# Runs                     int64
# Highest_innes_score     object
# Ave                    float64
# Balls_faced              int32
# Batting_Strik_Rate     float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_year              int32
# Final_year               int32
# country                 object
# dtype: object

# %%
# Question buil out career_lengh column 
#int convert rookie/final year and soustract

# %%
df['career_length'] = df['Final_year'] - df['Rookie_year']

# %%
df
# Out:
#           Player  Matches  Inns  not_outs  Runs Highest_innes_score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      AC Voges        20    31         7  1485                269*  61.87
# 2    RG Pollock        23    41         4  2256                 274  60.97
# 3    GA Headley        22    40         4  2190                270*  60.83
# 5   H Sutcliffe        54    84         9  4555                 194  60.73
# ..           ...      ...   ...       ...   ...                 ...    ...
# 62   KD Walters        74   125        14  5357                 250  48.26
# 63     GC Smith       117   205        13  9265                 277  48.25
# 64  WH Ponsford        29    48         4  2122                 266  48.22
# 65    SJ McCabe        39    62         5  2748                 232  48.21
# 66   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
#calculations with a dataframe

# %%
#Question 1 -> cricketers in this DF what is the average length

# %%
df['career_length'].mean()
# Out:
# 12.983870967741936

# %%
#Question 2 -> avg batting_strike_rate for cricketers who played over 10 years

# %%
df[df['career_length'] > 10]['Batting_Strik_Rate'].mean()
# Out:
# 49.082325581395345

# %%
#Question 3 find number of cricketers who played before 1960

# %%
df[df['Rookie_year'] < 1960]['Player'].count()
# Out:
# 22

# %%
#Question 4 Max highest Inns score by country

# %%
df.groupby('country')['Highest_innes_score'].max().to_frame('Higinncountry').reset_index().sort_values('Higinncountry')
# Out:
#      country Higinncountry
# 12      ZIM)          232*
# 7        NZ)           251
# 6       IND)          254*
# 4    ICC/SA)           277
# 9        SA)          278*
# 8       PAK)           313
# 2   ICC/IND)           319
# 3   ICC/PAK)           329
# 1       ENG)           364
# 11       WI)          365*
# 10       SL)           374
# 0       AUS)           380
# 5    ICC/WI)          400*

# %%
#Question 5 hundreds , fifties ducks (0) AVG by Country

# %%
df.groupby('country')[['100', '50', '0']].mean()
# Out:
#                 100      50          0
# country
# AUS)      20.625000  28.375   8.562500
# ENG)      13.500000  22.500   4.416667
# ICC/IND)  29.500000  47.500  12.000000
# ICC/PAK)  25.000000  46.000  15.000000
# ICC/SA)   36.000000  48.000  13.500000
# ICC/WI)   34.000000  48.000  17.000000
# IND)      24.200000  31.000   9.000000
# NZ)       32.000000  35.000  11.000000
# PAK)      17.800000  23.800   7.800000
# SA)        9.800000  20.200   3.400000
# SL)       28.666667  44.000  12.333333
# WI)       16.625000  25.625   7.250000
# ZIM)      12.000000  27.000   5.000000
