# %%
import pandas as pd

# %%
df = pd.read_csv("donnees_marketing_banque.csv" , sep=';')

# %%
df
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Affichons les 5 premieres lignes de notre base de données
df.head()
# Out:
#     id  age           job  marital  education default  balance housing loan  \
# 0  id1   58    management  married   tertiary      no   2143.0     yes   no
# 1  id2   44    technician   single  secondary      no     29.0     yes   no
# 2  id3   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3  id4   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4  id5   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Affichons les dernieres lignes de notre base de données
df.tail()
# Out:
#             id  age           job   marital  education default  balance  \
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45206      no   no   cellular   17   nov       977         3     -1         0
# 45207      no   no   cellular   17   nov       456         2     -1         0
# 45208      no   no   cellular   17   nov      1127         5    184         3
# 45209      no   no  telephone   17   nov       508         4     -1         0
# 45210      no   no   cellular   17   nov       361         2    188        11
#
#       poutcome    y
# 45206  unknown  yes
# 45207  unknown  yes
# ...

# %%
# Affichons les 10 premieres lignes de notre base de données
df.tail(10)
# Out:
#             id  age           job   marital  education default  balance  \
# 45201  id45202   53    management   married   tertiary      no    583.0
# 45202  id45203   34        admin.    single  secondary      no    557.0
# 45203  id45204   23       student    single   tertiary      no    113.0
# 45204  id45205   73       retired   married  secondary      no   2850.0
# 45205  id45206   25    technician    single  secondary      no    505.0
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45201      no   no   cellular   17   nov       226         1    184         4
# ...

# %%
# Listes des colonnes 
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Natures des données de la base dtypes
df.dtypes
# Out:
# id            object
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %% [markdown]
# ## combien de clients combien de variables

# %%
# Dimension du tableau 
df.shape
# Out:
# (45211, 18)

# %% [markdown]
# ## Description Rapide de la Base

# %%
# Analyse statistique quatitatitve
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45206.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.403707     15.806419    258.163080      2.763841
# std       10.623372    3044.906741      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Analyse statistique qualitatitve 
# Include 'All'
df.describe( include = 'all')
# Out:
#            id           age          job  marital  education default  \
# count   45211  45211.000000        45211    45211      45211   45211
# unique  45211           NaN           12        3          4       2
# top       id1           NaN  blue-collar  married  secondary      no
# freq        1           NaN         9732    27214      23202   44396
# mean      NaN     40.931477          NaN      NaN        NaN     NaN
# std       NaN     10.623372          NaN      NaN        NaN     NaN
# min       NaN     10.000000          NaN      NaN        NaN     NaN
# 25%       NaN     33.000000          NaN      NaN        NaN     NaN
# 50%       NaN     39.000000          NaN      NaN        NaN     NaN
# 75%       NaN     48.000000          NaN      NaN        NaN     NaN
# max       NaN     95.000000          NaN      NaN        NaN     NaN
#
#               balance housing   loan   contact           day  month  \
# count    45206.000000   45211  45211     45211  45211.000000  45211
# ...

# %%
# Modalité de la variables education
df['education']
# Out:
# 0         tertiary
# 1        secondary
# 2        secondary
# 3          unknown
# 4          unknown
#            ...
# 45206     tertiary
# 45207      primary
# 45208    secondary
# 45209    secondary
# 45210    secondary
# Name: education, Length: 45211, dtype: object

# %%
df.education.unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
df['education'].value_counts()
# Out:
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
df['education'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='education'>

# %% [markdown]
# ## Traitement des valeurs manquantes
# ## Handling missing values

# %%
# Nombre de valeurs manquante par variable
# Number of missing values per variable
df.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      5
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ## Traitement des valeus manquantes
# ## Processing missing values

# %%
# Supprimer les lignes manquantes ; Delete missing lines
df_delete_missing = df.dropna(axis=0)

# %%
df_delete_missing.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45206.000000   45206.000000  45206.000000  45206.000000  45206.000000
# mean      40.930828    1362.403707     15.807614    258.161616      2.764036
# std       10.623495    3044.906741      8.322160    257.539139      3.098137
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45206.000000  45206.000000
# mean      40.202385      0.580388
# std      100.133346      2.303560
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Remplacer une les valeurs manquantes par une valeur specifiques ;
# Replace one of the missing values with a specific value
df_remplacer = df.fillna(0)
df_remplacer.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.253036     15.806419    258.163080      2.763841
# std       10.623372    3044.772068      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Solution remplacons les valeurs manquantes par la moyennes 
# Other Solution replace missing values with averages

# %%
# Selection d'une colonne ;  Column selection
Avg = df['balance'].mean()
Avg
# Out:
# 1362.4037074724595

# %%
df_remplacer = df.fillna(Avg)
df_remplacer.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.931477    1362.403707     15.806419    258.163080      2.763841
# std       10.623372    3044.738361      8.322476    257.527812      3.098021
# min       10.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# Verifions s'il y'a plus de valeurs manquantes 
# Check if there are more missing values 
df_remplacer.isnull().sum()
# Out:
# id           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ## Suppression des colonnes inutiles
# ## Delete unnecessary columns

# %%
df_without_month_day = df.drop(['month','day'], axis = 1)
df_without_month_day
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# ## Choisir une ou des colonnes specifiques

# %% [markdown]
# ## Select one or more specific columns

# %%
# Choisir et d'ecrire une variable a partir du nom premiere approche

# %%
age = df['age']
print (age)
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %%
# Type de la colonne
# Column type
type(age)
# Out:
# pandas.core.series.Series

# %%
# statistiques de l'age 
# age statistics 
df['age'].describe()
# Out:
# count    45211.000000
# mean        40.931477
# std         10.623372
# min         10.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %% [markdown]
# ## choisir et decrire plusieurs variables a partir des noms
# ## select and describe several variables by name

# %%
base_select = df[['age','loan','education']]
base_select
# Out:
#        age loan  education
# 0       58   no   tertiary
# 1       44   no  secondary
# 2       33  yes  secondary
# 3       47   no    unknown
# 4       33   no    unknown
# ...    ...  ...        ...
# 45206   51   no   tertiary
# 45207   71   no    primary
# 45208   72   no  secondary
# 45209   57   no  secondary
# 45210   37   no  secondary
#
# [45211 rows x 3 columns]

# %%
type(base_select)
# Out:
# pandas.core.frame.DataFrame

# %%
base_select.describe()
# Out:
#                 age
# count  45211.000000
# mean      40.931477
# std       10.623372
# min       10.000000
# 25%       33.000000
# 50%       39.000000
# 75%       48.000000
# max       95.000000

# %% [markdown]
# ## Selection d'un perimetre d'analyse
# ## Selection of an analysis perimeter

# %%
#Premiere Approche : #First Approach
#Selection des clients qui on plus de 18 ans dans notre base de données : Selection of customers over 18 in our database
df["age"]>=18
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45206    True
# 45207    True
# 45208    True
# 45209    True
# 45210    True
# Name: age, Length: 45211, dtype: bool

# %%
base_majeur = df[df["age"]>=18]
base_majeur
# Out:
#             id  age           job   marital  education default  balance  \
# 0          id1   58    management   married   tertiary      no   2143.0
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 3          id4   47   blue-collar   married    unknown      no   1506.0
# 4          id5   33       unknown    single    unknown      no      1.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45206  id45207   51    technician   married   tertiary      no    825.0
# 45207  id45208   71       retired  divorced    primary      no   1729.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
base_majeur.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45203.000000   45198.000000  45203.000000  45203.000000  45203.000000
# mean      40.936133    1362.631997     15.808331    258.168816      2.764153
# std       10.618494    3045.126997      8.321971    257.548471      3.098206
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     449.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45203.000000  45203.000000
# mean      40.205119      0.580426
# std      100.136106      2.303632
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
# On veut l'age et le niveau d'éducation qui est le secondaire : We want the age and level of education which is high school 
base_majeur = df[(df["age"] >= 18) & (df["education"] == "secondary")]
base_majeur
# Out:
#             id  age           job   marital  education default  balance  \
# 1          id2   44    technician    single  secondary      no     29.0
# 2          id3   33  entrepreneur   married  secondary      no      2.0
# 9         id10   43    technician    single  secondary      no      NaN
# 10        id11   41        admin.  divorced  secondary      no    270.0
# 11        id12   29        admin.    single  secondary      no    390.0
# ...        ...  ...           ...       ...        ...     ...      ...
# 45204  id45205   73       retired   married  secondary      no   2850.0
# 45205  id45206   25    technician    single  secondary      no    505.0
# 45208  id45209   72       retired   married  secondary      no   5715.0
# 45209  id45210   57   blue-collar   married  secondary      no    668.0
# 45210  id45211   37  entrepreneur   married  secondary      no   2971.0
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
base_majeur.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  23199.000000  23197.000000  23199.000000  23199.000000  23199.000000
# mean      39.964352   1155.090184     15.760550    258.699556      2.701022
# std       10.159050   2558.490233      8.306735    253.324101      2.985916
# min       18.000000  -8019.000000      1.000000      0.000000      1.000000
# 25%       32.000000     55.000000      8.000000    105.000000      1.000000
# 50%       38.000000    392.000000     16.000000    183.000000      2.000000
# 75%       47.000000   1234.000000     21.000000    321.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     55.000000
#
#               pdays      previous
# count  23199.000000  23199.000000
# mean      42.359110      0.567826
# std      103.595216      1.849975
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# ...

# %%
base_majeur['education'].unique()
# Out:
# array(['secondary'], dtype=object)

# %%
#Creation d'une colonnes tranche d'age entre 18ans et 25 ans, de 25 a 50 et plus : Creation of an age range column from 18 to 25, from 25 to 50 and over 
#np.nan
import numpy as np
df['Age_range'] = np.nan

# %%
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y', 'Age_range'],
#       dtype='object')

# %%
df['Age_range'][df['age']< 18] = "<18"
df['Age_range'][(df['age']>= 18) & (df['age'] < 25)] = "18-25"
df['Age_range'][(df['age']>= 25) & (df['age'] < 50)] = "25-50"
df['Age_range'][(df['age']>= 50)] = ">=50"
# Out:
# C:\Users\MOHAMED FAYE\AppData\Local\Temp\ipykernel_8856\1857707746.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Age_range'][df['age']< 18] = "<18"
# ...

# %%
df['Age_range'].unique()
# Out:
# array(['>=50', '25-50', '<18', '18-25'], dtype=object)

# %%
df.dtypes
# Out:
# id            object
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# y             object
# Age_range     object
# dtype: object

# %%
df['Age_range'].value_counts()
# Out:
# Age_range
# 25-50    34203
# >=50     10192
# 18-25      808
# <18          8
# Name: count, dtype: int64

# %%
df['Age_range'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Age_range'>

# %%
#le solde moyen des individu par tranches d'age
#average balance of individuals by age group
df.groupby("Age_range")["balance"].mean()
# Out:
# Age_range
# 18-25     916.949257
# 25-50    1236.063830
# <18        72.625000
# >=50     1822.763788
# Name: balance, dtype: float64

# %%
#filtre des clients de plus de 25 ans et calcule l'age moyen en fonction du niveau d'éducation 
#filter customers over 25 and calculate average age based on education level 
df[df["age"]>25].groupby('education')["age"].mean()
# Out:
# education
# primary      46.197571
# secondary    40.616153
# tertiary     39.883466
# unknown      45.830576
# Name: age, dtype: float64

# %%
# Segmentation par profession et statut marital
segmentation = df.groupby(['job', 'marital']).agg({
    'age': 'mean',              
    'balance': 'mean',          
    'duration': 'mean',                          
}).reset_index()

# %%
# Ajouter une colonne pour le nombre total de clients dans chaque segment
segmentation['total_clients'] = df.groupby(['job', 'marital']).size().reset_index(name='total_clients')['total_clients']

# %%
# Trier par nombre total de clients (pour identifier les segments les plus importants)
segmentation = segmentation.sort_values(by='total_clients', ascending=False)

# %%
# Afficher les résultats
segmentation
# Out:
#               job   marital        age      balance    duration  total_clients
# 4     blue-collar   married  41.549799  1113.165901  255.627009           6968
# 13     management   married  42.678333  1828.159444  251.433889           5400
# 28     technician   married  41.854640  1307.399556  246.574038           4052
# 14     management    single  34.494401  1700.219545  257.789956           2947
# 1          admin.   married  41.502414  1281.409580  242.796881           2693
# 29     technician    single  33.921374  1284.591291  266.890840           2620
# 22       services   married  40.672622  1088.847528  252.961363           2407
# 5     blue-collar    single  33.550149  1056.105263  284.140516           2014
# 16        retired   married  61.728481  2141.203468  286.749856           1731
# 2          admin.    single  34.171875  1020.739005  247.622685           1728
# 23       services    single  32.867279   887.324708  270.476628           1198
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Tracer un graphique en barres pour les segments les plus importants
plt.figure(figsize=(14, 8))
sns.barplot(data=segmentation.head(10), x='job', y='total_clients', hue='marital')
plt.title('Top 10 des Segments par Profession et Statut Marital')
plt.xlabel('Profession')
plt.ylabel('Nombre de Clients')
plt.xticks(rotation=45)
plt.legend(title='Statut Marital')
plt.show()
